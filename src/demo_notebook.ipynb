# %%
from llm_client import prompt_scadsai_llm
from knime_io import load_tools_metadata
from Vectorstore import VectorStore
from rag_functions import build_all_docs

data = load_tools_metadata("data/tools_metadata.json")

texts, metas = build_all_docs(data)
print(f"Dokumente für Embedding: {len(texts)}")
# Out:
# Dokumente für Embedding: 3787
